# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\HP\Downloads\Uber_Dirty_Dataset.xlsx")
df
# Out:
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type   Fare  \
# 0    UBER1000    DRV299       PSG351         NaN     New York      NaN    NaN
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix      NaN    NaN
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.22
# 3    UBER1003    DRV972       PSG155         NaN          NaN     Mini    NaN
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.30
# ..        ...       ...          ...         ...          ...      ...    ...
# 995  UBER1995    DRV700       PSG943    New York     New York      NaN    NaN
# 996  UBER1996    DRV212       PSG157         NaN          NaN    Sedan -10.00
# 997  UBER1997    DRV457       PSG336     Houston  Los Angeles      NaN    NaN
# 998  UBER1998    DRV778       PSG294         NaN          NaN   Luxury -10.00
# 999  UBER1999    DRV389       PSG621     Phoenix      Houston    Sedan -10.00
#
# ...

# %%
df['Rating'].fillna(df['Rating'].mean(),inplace=True)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11628\3490161922.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'].fillna(df['Rating'].mean(),inplace=True)
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type   Fare  \
# 0    UBER1000    DRV299       PSG351         NaN     New York      NaN    NaN
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix      NaN    NaN
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.22
# ...

# %%
df['Rating']=df['Rating'].round()
df
# Out:
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type   Fare  \
# 0    UBER1000    DRV299       PSG351         NaN     New York      NaN    NaN
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix      NaN    NaN
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.22
# 3    UBER1003    DRV972       PSG155         NaN          NaN     Mini    NaN
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.30
# ..        ...       ...          ...         ...          ...      ...    ...
# 995  UBER1995    DRV700       PSG943    New York     New York      NaN    NaN
# 996  UBER1996    DRV212       PSG157         NaN          NaN    Sedan -10.00
# 997  UBER1997    DRV457       PSG336     Houston  Los Angeles      NaN    NaN
# 998  UBER1998    DRV778       PSG294         NaN          NaN   Luxury -10.00
# 999  UBER1999    DRV389       PSG621     Phoenix      Houston    Sedan -10.00
#
# ...

# %%
df['Ride_Time']=df['Ride_Time'].fillna(method='ffill')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11628\2610619067.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Ride_Time']=df['Ride_Time'].fillna(method='ffill')
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type   Fare  \
# 0    UBER1000    DRV299       PSG351         NaN     New York      NaN    NaN
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix      NaN    NaN
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.22
# 3    UBER1003    DRV972       PSG155         NaN          NaN     Mini    NaN
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.30
# ..        ...       ...          ...         ...          ...      ...    ...
# 995  UBER1995    DRV700       PSG943    New York     New York      NaN    NaN
# 996  UBER1996    DRV212       PSG157         NaN          NaN    Sedan -10.00
# ...

# %%
df['Pickup_City']=df['Pickup_City'].fillna(method='bfill')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11628\3651724253.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Pickup_City']=df['Pickup_City'].fillna(method='bfill')
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type   Fare  \
# 0    UBER1000    DRV299       PSG351     Chicago     New York      NaN    NaN
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix      NaN    NaN
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.22
# 3    UBER1003    DRV972       PSG155     Phoenix          NaN     Mini    NaN
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.30
# ..        ...       ...          ...         ...          ...      ...    ...
# 995  UBER1995    DRV700       PSG943    New York     New York      NaN    NaN
# 996  UBER1996    DRV212       PSG157     Houston          NaN    Sedan -10.00
# ...

# %%
df.isnull().sum()
# Out:
# Ride_ID             0
# Driver_ID           0
# Passenger_ID        0
# Pickup_City         0
# Drop_City         299
# Car_Type          273
# Fare              349
# Payment_Method    407
# Rating              0
# Ride_Time           0
# dtype: int64

# %%
df['Drop_City']=df['Drop_City'].fillna(method='bfill')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11628\3279106256.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Drop_City']=df['Drop_City'].fillna(method='bfill')
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type   Fare  \
# 0    UBER1000    DRV299       PSG351     Chicago     New York      NaN    NaN
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix      NaN    NaN
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.22
# 3    UBER1003    DRV972       PSG155     Phoenix      Houston     Mini    NaN
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.30
# ..        ...       ...          ...         ...          ...      ...    ...
# 995  UBER1995    DRV700       PSG943    New York     New York      NaN    NaN
# 996  UBER1996    DRV212       PSG157     Houston     New York    Sedan -10.00
# ...

# %%
df['Car_Type']=df['Car_Type'].fillna(method='bfill')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11628\1357251567.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Car_Type']=df['Car_Type'].fillna(method='bfill')
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type   Fare  \
# 0    UBER1000    DRV299       PSG351     Chicago     New York     Mini    NaN
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix     Mini    NaN
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.22
# 3    UBER1003    DRV972       PSG155     Phoenix      Houston     Mini    NaN
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.30
# ..        ...       ...          ...         ...          ...      ...    ...
# 995  UBER1995    DRV700       PSG943    New York     New York    Sedan    NaN
# 996  UBER1996    DRV212       PSG157     Houston     New York    Sedan -10.00
# ...

# %%
df['Fare'].fillna(df['Fare'].mean(),inplace=True)
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11628\457988773.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fare'].fillna(df['Fare'].mean(),inplace=True)
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type  \
# 0    UBER1000    DRV299       PSG351     Chicago     New York     Mini
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix     Mini
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini
# ...

# %%
df['Fare']=df['Fare'].round()
df
# Out:
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type  Fare  \
# 0    UBER1000    DRV299       PSG351     Chicago     New York     Mini  23.0
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix     Mini  23.0
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.0
# 3    UBER1003    DRV972       PSG155     Phoenix      Houston     Mini  23.0
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.0
# ..        ...       ...          ...         ...          ...      ...   ...
# 995  UBER1995    DRV700       PSG943    New York     New York    Sedan  23.0
# 996  UBER1996    DRV212       PSG157     Houston     New York    Sedan -10.0
# 997  UBER1997    DRV457       PSG336     Houston  Los Angeles   Luxury  23.0
# 998  UBER1998    DRV778       PSG294     Phoenix  Los Angeles   Luxury -10.0
# 999  UBER1999    DRV389       PSG621     Phoenix      Houston    Sedan -10.0
#
# ...

# %%
df['Payment_Method']=df['Payment_Method'].fillna(method='ffill')
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_11628\3888657618.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Payment_Method']=df['Payment_Method'].fillna(method='ffill')
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type  Fare  \
# 0    UBER1000    DRV299       PSG351     Chicago     New York     Mini  23.0
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix     Mini  23.0
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.0
# 3    UBER1003    DRV972       PSG155     Phoenix      Houston     Mini  23.0
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.0
# ..        ...       ...          ...         ...          ...      ...   ...
# 995  UBER1995    DRV700       PSG943    New York     New York    Sedan  23.0
# 996  UBER1996    DRV212       PSG157     Houston     New York    Sedan -10.0
# ...

# %%
df.isnull().sum()
# Out:
# Ride_ID           0
# Driver_ID         0
# Passenger_ID      0
# Pickup_City       0
# Drop_City         0
# Car_Type          0
# Fare              0
# Payment_Method    0
# Rating            0
# Ride_Time         0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type  Fare  \
# 0    UBER1000    DRV299       PSG351     Chicago     New York     Mini  23.0
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix     Mini  23.0
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.0
# 3    UBER1003    DRV972       PSG155     Phoenix      Houston     Mini  23.0
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.0
# ..        ...       ...          ...         ...          ...      ...   ...
# 995  UBER1995    DRV700       PSG943    New York     New York    Sedan  23.0
# 996  UBER1996    DRV212       PSG157     Houston     New York    Sedan -10.0
# 997  UBER1997    DRV457       PSG336     Houston  Los Angeles   Luxury  23.0
# 998  UBER1998    DRV778       PSG294     Phoenix  Los Angeles   Luxury -10.0
# 999  UBER1999    DRV389       PSG621     Phoenix      Houston    Sedan -10.0
#
# ...

# %%
print(df)
# Out:
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type  Fare  \
# 0    UBER1000    DRV299       PSG351     Chicago     New York     Mini  23.0
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix     Mini  23.0
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.0
# 3    UBER1003    DRV972       PSG155     Phoenix      Houston     Mini  23.0
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.0
# ..        ...       ...          ...         ...          ...      ...   ...
# 995  UBER1995    DRV700       PSG943    New York     New York    Sedan  23.0
# 996  UBER1996    DRV212       PSG157     Houston     New York    Sedan -10.0
# 997  UBER1997    DRV457       PSG336     Houston  Los Angeles   Luxury  23.0
# 998  UBER1998    DRV778       PSG294     Phoenix  Los Angeles   Luxury -10.0
# 999  UBER1999    DRV389       PSG621     Phoenix      Houston    Sedan -10.0
#
# ...

# %%
df.head(10)
# Out:
#     Ride_ID Driver_ID Passenger_ID  Pickup_City    Drop_City Car_Type  Fare  \
# 0  UBER1000    DRV299       PSG351      Chicago     New York     Mini  23.0
# 1  UBER1001    DRV524       PSG312      Chicago      Phoenix     Mini  23.0
# 2  UBER1002    DRV191       PSG881      Houston      Houston     Mini  78.0
# 3  UBER1003    DRV972       PSG155      Phoenix      Houston     Mini  23.0
# 4  UBER1004    DRV626       PSG927      Phoenix  Los Angeles   Luxury  60.0
# 5  UBER1005    DRV594       PSG733  Los Angeles  Los Angeles   Luxury -10.0
# 6  UBER1006    DRV509       PSG623  Los Angeles      Chicago   Luxury  25.0
# 7  UBER1007    DRV385       PSG811  Los Angeles      Chicago     Mini -10.0
# 8  UBER1008    DRV584       PSG571      Chicago      Phoenix     Mini -10.0
# 9  UBER1009    DRV664       PSG810      Houston      Chicago      SUV  23.0
#
#   Payment_Method  Rating           Ride_Time
# 0           Cash     2.0 2023-07-14 13:35:22
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Ride_ID         1000 non-null   object
#  1   Driver_ID       1000 non-null   object
#  2   Passenger_ID    1000 non-null   object
#  3   Pickup_City     1000 non-null   object
#  4   Drop_City       1000 non-null   object
#  5   Car_Type        1000 non-null   object
#  6   Fare            1000 non-null   float64
#  7   Payment_Method  1000 non-null   object
#  8   Rating          1000 non-null   float64
#  9   Ride_Time       1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(7)
# memory usage: 78.3+ KB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Ride_ID, Driver_ID, Passenger_ID, Pickup_City, Drop_City, Car_Type, Fare, Payment_Method, Rating, Ride_Time]
# Index: []

# %%
df
# Out:
#       Ride_ID Driver_ID Passenger_ID Pickup_City    Drop_City Car_Type  Fare  \
# 0    UBER1000    DRV299       PSG351     Chicago     New York     Mini  23.0
# 1    UBER1001    DRV524       PSG312     Chicago      Phoenix     Mini  23.0
# 2    UBER1002    DRV191       PSG881     Houston      Houston     Mini  78.0
# 3    UBER1003    DRV972       PSG155     Phoenix      Houston     Mini  23.0
# 4    UBER1004    DRV626       PSG927     Phoenix  Los Angeles   Luxury  60.0
# ..        ...       ...          ...         ...          ...      ...   ...
# 995  UBER1995    DRV700       PSG943    New York     New York    Sedan  23.0
# 996  UBER1996    DRV212       PSG157     Houston     New York    Sedan -10.0
# 997  UBER1997    DRV457       PSG336     Houston  Los Angeles   Luxury  23.0
# 998  UBER1998    DRV778       PSG294     Phoenix  Los Angeles   Luxury -10.0
# 999  UBER1999    DRV389       PSG621     Phoenix      Houston    Sedan -10.0
#
# ...
